# %% [markdown]
# <a href="https://colab.research.google.com/github/sunitharamu-1983/GENAI-Learning-Journey/blob/main/Word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 61.6 MB/s eta 0:00:00
# ...

# %%
import gensim.downloader as api
wv = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
wv

# %%
unique words -> tokenization
n-grams - 1,2,3

# %%
wv.most_similar('king')
# Out:
# [('kings', 0.7138045430183411),
#  ('queen', 0.6510956883430481),
#  ('monarch', 0.6413194537162781),
#  ('crown_prince', 0.6204220056533813),
#  ('prince', 0.6159993410110474),
#  ('sultan', 0.5864824056625366),
#  ('ruler', 0.5797567367553711),
#  ('princes', 0.5646552443504333),
#  ('Prince_Paras', 0.5432944297790527),
#  ('throne', 0.5422105193138123)]

# %%
len(wv['kings'])
# Out:
# 300

# %%
wv.most_similar(positive=['king','woman'], negative=['man'])
# Out:
# [('queen', 0.7118193507194519),
#  ('monarch', 0.6189674139022827),
#  ('princess', 0.5902431011199951),
#  ('crown_prince', 0.5499460697174072),
#  ('prince', 0.5377321839332581),
#  ('kings', 0.5236844420433044),
#  ('Queen_Consort', 0.5235945582389832),
#  ('queens', 0.518113374710083),
#  ('sultan', 0.5098593235015869),
#  ('monarchy', 0.5087411403656006)]

# %%
len(wv['bank'])
# Out:
# 300

# %%
wv.most_similar('banks')
# Out:
# [('bank', 0.7440758347511292),
#  ('lenders', 0.660046398639679),
#  ('banking', 0.6438172459602356),
#  ('mortgage_lenders', 0.6358486413955688),
#  ('megabanks', 0.6172765493392944),
#  ('institutions', 0.6150783896446228),
#  ('brokerages', 0.6133029460906982),
#  ('lender', 0.6090298295021057),
#  ('depositors', 0.6050993204116821),
#  ('Banks', 0.6024675369262695)]

# %%
wv.most_similar('interest')
# Out:
# [('Interest', 0.6201675534248352),
#  ('interst', 0.6111735701560974),
#  ('inter_est', 0.4959198534488678),
#  ('terest', 0.4737527370452881),
#  ('intrest', 0.47011181712150574),
#  ('interests', 0.4595865309238434),
#  ('desire', 0.43578776717185974),
#  ('enthusiasm', 0.4237188696861267),
#  ('curiosity', 0.4213345944881439),
#  ('admiration', 0.41674670577049255)]

# %%
wv.most_similar('chatgpt')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_603/3809860635.py in <cell line: 0>()
# ----> 1 wv.most_similar('chatgpt')
#
# /usr/local/lib/python3.12/dist-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     841
#     842         # compute the weighted average of all keys
# --> 843         mean = self.get_mean_vector(keys, weight, pre_normalize=True, post_normalize=True, ignore_missing=False)
#     844         all_keys = [
#     845             self.get_index(key) for key in keys if isinstance(key, _KEY_TYPES) and self.has_index_for(key)
#
# /usr/local/lib/python3.12/dist-packages/gensim/models/keyedvectors.py in get_mean_vector(self, keys, weights, pre_normalize, post_normalize, ignore_missing)
#     516                 total_weight += abs(weights[idx])
# ...

# %%
wv.most_similar('the')
# Out:
# [('this', 0.5937379002571106),
#  ('in', 0.5429295897483826),
#  ('that', 0.5262570381164551),
#  ('ofthe', 0.515028178691864),
#  ('another', 0.47483521699905396),
#  ('however', 0.4748331904411316),
#  ('one', 0.4665869176387787),
#  ('entire', 0.461982399225235),
#  ('its', 0.460594117641449),
#  ('which', 0.4595310389995575)]

# %%
wv.most_similar('run')
# Out:
# [('runs', 0.6569936275482178),
#  ('running', 0.6062965989112854),
#  ('drive', 0.4834049642086029),
#  ('ran', 0.4764978289604187),
#  ('scamper', 0.46932122111320496),
#  ('tworun_double', 0.46402227878570557),
#  ('go', 0.4631645083427429),
#  ('twoout', 0.45749351382255554),
#  ('walk', 0.45697975158691406),
#  ('Mark_Grudzielanek_singled', 0.4565179646015167)]

# %%
the      cat           sat
[1,2,3]. [4, 5, 7].    [3,5,7]
 Word2vec



 Sent2Vec
[1+4+3/3,   2+5+5/3.    3+7+7/3]
