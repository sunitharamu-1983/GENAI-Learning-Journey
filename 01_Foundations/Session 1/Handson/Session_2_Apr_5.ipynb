# %% [markdown]
# <a href="https://colab.research.google.com/github/sunitharamu-1983/GENAI-Learning-Journey/blob/main/Session_2_Apr_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
documents = {
    "S1": "The best homemade pizza recipe for beginners",
    "S2": "How to make the best pizza dough from scratch recipe",
    "S3": "Top 10 tips for baking pizza at home for beginners",
    "S4": "Easy pasta recipes and Italian cooking techniques",
    "S5": "A guide to building your own outdoor pizza oven in summer",
    "S6": "The history of pizza from Naples to New York for foodies",
    "S7": "Healthy meal prep ideas and cooking tips for temperature control",
    "S8": "Best wood-fired pizza restaurants in the best cities",
    "S9": "How to choose the right flour for homemade bread and pizza",
    "S10": "Italian cheese varieties and their uses in traditional cooking"
}

# %%
from google.colab import drive
drive.mount('/content/drive')

#PARSING THE HTML TEXT
from bs4 import BeautifulSoup
import pandas as pd

with open('/content/drive/MyDrive/Colab Notebooks/index.html', 'r') as f:
    contents = f.read()

    soup = BeautifulSoup(contents, "html.parser")
    results = soup.find_all('li')

    df = pd.DataFrame({'Names': results})
    df.to_csv('names.csv', index=False, encoding='utf-8')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
text = soup.get_text(separator='\n', strip=True)
print(text)
# Out:
# S1: The best homemade pizza recipe for beginners,
# 		S2: How to make the best pizza dough from scratch recipe,
# 		S3: Top 10 tips for baking pizza at home for beginners,
# 		S4: Easy pasta recipes and Italian cooking techniques,
# 		S5: A guide to building your own outdoor pizza oven in summer,
# 		S6: The history of pizza from Naples to New York for foodies,
# 		S7: Healthy meal prep ideas and cooking tips for temperature control,
# 		S8: Best wood-fired pizza restaurants in the best cities,
# 		S9: How to choose the right flour for homemade bread and pizza,
# 		S10: Italian cheese varieties and their uses in traditional cooking

# %%
# Convert text from index.html to dictionary in python and save it under documents dictionary
# Splits by comma first, then by colon for each pair
documents = {k.strip(): v.strip() for k, v in (item.split(':') for item in text.split(','))}

print (documents)
# Out:
# {'S1': 'The best homemade pizza recipe for beginners', 'S2': 'How to make the best pizza dough from scratch recipe', 'S3': 'Top 10 tips for baking pizza at home for beginners', 'S4': 'Easy pasta recipes and Italian cooking techniques', 'S5': 'A guide to building your own outdoor pizza oven in summer', 'S6': 'The history of pizza from Naples to New York for foodies', 'S7': 'Healthy meal prep ideas and cooking tips for temperature control', 'S8': 'Best wood-fired pizza restaurants in the best cities', 'S9': 'How to choose the right flour for homemade bread and pizza', 'S10': 'Italian cheese varieties and their uses in traditional cooking'}

# %% [markdown]
# # **TOKENIZATION**

# %%
documents['S1'].lower().split()
# Out:
# ['the', 'best', 'homemade', 'pizza', 'recipe', 'for', 'beginners']

# %%
for doc_id, text in documents.items():
  print(doc_id," : ", len(text.lower().split()), " Token", " : ",  text.lower().split())
# Out:
# S1  :  7  Token  :  ['the', 'best', 'homemade', 'pizza', 'recipe', 'for', 'beginners']
# S2  :  10  Token  :  ['how', 'to', 'make', 'the', 'best', 'pizza', 'dough', 'from', 'scratch', 'recipe']
# S3  :  10  Token  :  ['top', '10', 'tips', 'for', 'baking', 'pizza', 'at', 'home', 'for', 'beginners']
# S4  :  7  Token  :  ['easy', 'pasta', 'recipes', 'and', 'italian', 'cooking', 'techniques']
# S5  :  11  Token  :  ['a', 'guide', 'to', 'building', 'your', 'own', 'outdoor', 'pizza', 'oven', 'in', 'summer']
# S6  :  11  Token  :  ['the', 'history', 'of', 'pizza', 'from', 'naples', 'to', 'new', 'york', 'for', 'foodies']
# S7  :  10  Token  :  ['healthy', 'meal', 'prep', 'ideas', 'and', 'cooking', 'tips', 'for', 'temperature', 'control']
# S8  :  8  Token  :  ['best', 'wood-fired', 'pizza', 'restaurants', 'in', 'the', 'best', 'cities']
# S9  :  11  Token  :  ['how', 'to', 'choose', 'the', 'right', 'flour', 'for', 'homemade', 'bread', 'and', 'pizza']
# S10  :  9  Token  :  ['italian', 'cheese', 'varieties', 'and', 'their', 'uses', 'in', 'traditional', 'cooking']

# %% [markdown]
# # **STOP WORDS**

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
#print(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
len(stopwords.words('english'))
# Out:
# 198

# %%
STOPWORDS = stopwords.words('english')

for doc_id, text in documents.items():
  tokenized = text.lower().split()
  print("Before : ", tokenized)
  print("After : ",[word for word in tokenized if word not in STOPWORDS])
# Out:
# Before :  ['the', 'best', 'homemade', 'pizza', 'recipe', 'for', 'beginners']
# After :  ['best', 'homemade', 'pizza', 'recipe', 'beginners']
# Before :  ['how', 'to', 'make', 'the', 'best', 'pizza', 'dough', 'from', 'scratch', 'recipe']
# After :  ['make', 'best', 'pizza', 'dough', 'scratch', 'recipe']
# Before :  ['top', '10', 'tips', 'for', 'baking', 'pizza', 'at', 'home', 'for', 'beginners']
# After :  ['top', '10', 'tips', 'baking', 'pizza', 'home', 'beginners']
# Before :  ['easy', 'pasta', 'recipes', 'and', 'italian', 'cooking', 'techniques']
# After :  ['easy', 'pasta', 'recipes', 'italian', 'cooking', 'techniques']
# Before :  ['a', 'guide', 'to', 'building', 'your', 'own', 'outdoor', 'pizza', 'oven', 'in', 'summer']
# After :  ['guide', 'building', 'outdoor', 'pizza', 'oven', 'summer']
# Before :  ['the', 'history', 'of', 'pizza', 'from', 'naples', 'to', 'new', 'york', 'for', 'foodies']
# After :  ['history', 'pizza', 'naples', 'new', 'york', 'foodies']
# Before :  ['healthy', 'meal', 'prep', 'ideas', 'and', 'cooking', 'tips', 'for', 'temperature', 'control']
# After :  ['healthy', 'meal', 'prep', 'ideas', 'cooking', 'tips', 'temperature', 'control']
# Before :  ['best', 'wood-fired', 'pizza', 'restaurants', 'in', 'the', 'best', 'cities']
# After :  ['best', 'wood-fired', 'pizza', 'restaurants', 'best', 'cities']
# Before :  ['how', 'to', 'choose', 'the', 'right', 'flour', 'for', 'homemade', 'bread', 'and', 'pizza']
# After :  ['choose', 'right', 'flour', 'homemade', 'bread', 'pizza']
# Before :  ['italian', 'cheese', 'varieties', 'and', 'their', 'uses', 'in', 'traditional', 'cooking']
# After :  ['italian', 'cheese', 'varieties', 'uses', 'traditional', 'cooking']

# %% [markdown]
# ## **STEMMING & LEMMATIZATION**

# %%
from nltk.stem import PorterStemmer

# %%
# %%time
PorterStemmer().stem('reading')
# Out:
# CPU times: user 160 µs, sys: 0 ns, total: 160 µs
# Wall time: 165 µs
# 'read'

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# %%time
WordNetLemmatizer().lemmatize('reading')
# Out:
# CPU times: user 54 µs, sys: 5 µs, total: 59 µs
# Wall time: 63.4 µs
# 'reading'

# %%
# %%time
for doc_id, text in documents.items():
  tokenized = text.lower().split()
  print("Before : ", tokenized)
  print("After : ",[PorterStemmer().stem(word) for word in tokenized if word not in STOPWORDS])
# Out:
# Before :  ['the', 'best', 'homemade', 'pizza', 'recipe', 'for', 'beginners']
# After :  ['best', 'homemad', 'pizza', 'recip', 'beginn']
# Before :  ['how', 'to', 'make', 'the', 'best', 'pizza', 'dough', 'from', 'scratch', 'recipe']
# After :  ['make', 'best', 'pizza', 'dough', 'scratch', 'recip']
# Before :  ['top', '10', 'tips', 'for', 'baking', 'pizza', 'at', 'home', 'for', 'beginners']
# After :  ['top', '10', 'tip', 'bake', 'pizza', 'home', 'beginn']
# Before :  ['easy', 'pasta', 'recipes', 'and', 'italian', 'cooking', 'techniques']
# After :  ['easi', 'pasta', 'recip', 'italian', 'cook', 'techniqu']
# Before :  ['a', 'guide', 'to', 'building', 'your', 'own', 'outdoor', 'pizza', 'oven', 'in', 'summer']
# After :  ['guid', 'build', 'outdoor', 'pizza', 'oven', 'summer']
# Before :  ['the', 'history', 'of', 'pizza', 'from', 'naples', 'to', 'new', 'york', 'for', 'foodies']
# After :  ['histori', 'pizza', 'napl', 'new', 'york', 'foodi']
# Before :  ['healthy', 'meal', 'prep', 'ideas', 'and', 'cooking', 'tips', 'for', 'temperature', 'control']
# After :  ['healthi', 'meal', 'prep', 'idea', 'cook', 'tip', 'temperatur', 'control']
# Before :  ['best', 'wood-fired', 'pizza', 'restaurants', 'in', 'the', 'best', 'cities']
# After :  ['best', 'wood-fir', 'pizza', 'restaur', 'best', 'citi']
# Before :  ['how', 'to', 'choose', 'the', 'right', 'flour', 'for', 'homemade', 'bread', 'and', 'pizza']
# After :  ['choos', 'right', 'flour', 'homemad', 'bread', 'pizza']
# Before :  ['italian', 'cheese', 'varieties', 'and', 'their', 'uses', 'in', 'traditional', 'cooking']
# After :  ['italian', 'chees', 'varieti', 'use', 'tradit', 'cook']
# CPU times: user 4.74 ms, sys: 0 ns, total: 4.74 ms
# Wall time: 7.15 ms

# %%
# %%time
for doc_id, text in documents.items():
  tokenized = text.lower().split()
  print("Before : ", tokenized)
  print("After : ",[WordNetLemmatizer().lemmatize(word) for word in tokenized if word not in STOPWORDS])
# Out:
# Before :  ['the', 'best', 'homemade', 'pizza', 'recipe', 'for', 'beginners']
# After :  ['best', 'homemade', 'pizza', 'recipe', 'beginner']
# Before :  ['how', 'to', 'make', 'the', 'best', 'pizza', 'dough', 'from', 'scratch', 'recipe']
# After :  ['make', 'best', 'pizza', 'dough', 'scratch', 'recipe']
# Before :  ['top', '10', 'tips', 'for', 'baking', 'pizza', 'at', 'home', 'for', 'beginners']
# After :  ['top', '10', 'tip', 'baking', 'pizza', 'home', 'beginner']
# Before :  ['easy', 'pasta', 'recipes', 'and', 'italian', 'cooking', 'techniques']
# After :  ['easy', 'pasta', 'recipe', 'italian', 'cooking', 'technique']
# Before :  ['a', 'guide', 'to', 'building', 'your', 'own', 'outdoor', 'pizza', 'oven', 'in', 'summer']
# After :  ['guide', 'building', 'outdoor', 'pizza', 'oven', 'summer']
# Before :  ['the', 'history', 'of', 'pizza', 'from', 'naples', 'to', 'new', 'york', 'for', 'foodies']
# After :  ['history', 'pizza', 'naples', 'new', 'york', 'foodie']
# Before :  ['healthy', 'meal', 'prep', 'ideas', 'and', 'cooking', 'tips', 'for', 'temperature', 'control']
# After :  ['healthy', 'meal', 'prep', 'idea', 'cooking', 'tip', 'temperature', 'control']
# Before :  ['best', 'wood-fired', 'pizza', 'restaurants', 'in', 'the', 'best', 'cities']
# After :  ['best', 'wood-fired', 'pizza', 'restaurant', 'best', 'city']
# Before :  ['how', 'to', 'choose', 'the', 'right', 'flour', 'for', 'homemade', 'bread', 'and', 'pizza']
# After :  ['choose', 'right', 'flour', 'homemade', 'bread', 'pizza']
# Before :  ['italian', 'cheese', 'varieties', 'and', 'their', 'uses', 'in', 'traditional', 'cooking']
# After :  ['italian', 'cheese', 'variety', 'us', 'traditional', 'cooking']
# CPU times: user 1.02 ms, sys: 1e+03 ns, total: 1.02 ms
# Wall time: 1.02 ms

# %%
processed = {}
for doc_id, text in documents.items():
  tokenized = text.lower().split()
  print("Before : ", tokenized)
  print("After : ",[WordNetLemmatizer().lemmatize(word) for word in tokenized if word not in STOPWORDS])
  processed[doc_id] = [WordNetLemmatizer().lemmatize(word) for word in tokenized if word not in STOPWORDS]
# Out:
# Before :  ['the', 'best', 'homemade', 'pizza', 'recipe', 'for', 'beginners']
# After :  ['best', 'homemade', 'pizza', 'recipe', 'beginner']
# Before :  ['how', 'to', 'make', 'the', 'best', 'pizza', 'dough', 'from', 'scratch', 'recipe']
# After :  ['make', 'best', 'pizza', 'dough', 'scratch', 'recipe']
# Before :  ['top', '10', 'tips', 'for', 'baking', 'pizza', 'at', 'home', 'for', 'beginners']
# After :  ['top', '10', 'tip', 'baking', 'pizza', 'home', 'beginner']
# Before :  ['easy', 'pasta', 'recipes', 'and', 'italian', 'cooking', 'techniques']
# After :  ['easy', 'pasta', 'recipe', 'italian', 'cooking', 'technique']
# Before :  ['a', 'guide', 'to', 'building', 'your', 'own', 'outdoor', 'pizza', 'oven', 'in', 'summer']
# After :  ['guide', 'building', 'outdoor', 'pizza', 'oven', 'summer']
# Before :  ['the', 'history', 'of', 'pizza', 'from', 'naples', 'to', 'new', 'york', 'for', 'foodies']
# After :  ['history', 'pizza', 'naples', 'new', 'york', 'foodie']
# Before :  ['healthy', 'meal', 'prep', 'ideas', 'and', 'cooking', 'tips', 'for', 'temperature', 'control']
# After :  ['healthy', 'meal', 'prep', 'idea', 'cooking', 'tip', 'temperature', 'control']
# Before :  ['best', 'wood-fired', 'pizza', 'restaurants', 'in', 'the', 'best', 'cities']
# After :  ['best', 'wood-fired', 'pizza', 'restaurant', 'best', 'city']
# Before :  ['how', 'to', 'choose', 'the', 'right', 'flour', 'for', 'homemade', 'bread', 'and', 'pizza']
# After :  ['choose', 'right', 'flour', 'homemade', 'bread', 'pizza']
# Before :  ['italian', 'cheese', 'varieties', 'and', 'their', 'uses', 'in', 'traditional', 'cooking']
# After :  ['italian', 'cheese', 'variety', 'us', 'traditional', 'cooking']

# %%
processed
# Out:
# {'S1': ['best', 'homemade', 'pizza', 'recipe', 'beginner'],
#  'S2': ['make', 'best', 'pizza', 'dough', 'scratch', 'recipe'],
#  'S3': ['top', '10', 'tip', 'baking', 'pizza', 'home', 'beginner'],
#  'S4': ['easy', 'pasta', 'recipe', 'italian', 'cooking', 'technique'],
#  'S5': ['guide', 'building', 'outdoor', 'pizza', 'oven', 'summer'],
#  'S6': ['history', 'pizza', 'naples', 'new', 'york', 'foodie'],
#  'S7': ['healthy',
#   'meal',
#   'prep',
#   'idea',
#   'cooking',
#   'tip',
#   'temperature',
#   'control'],
#  'S8': ['best', 'wood-fired', 'pizza', 'restaurant', 'best', 'city'],
#  'S9': ['choose', 'right', 'flour', 'homemade', 'bread', 'pizza'],
#  'S10': ['italian', 'cheese', 'variety', 'us', 'traditional', 'cooking']}

# %%
unique_words = set()
for doc_id, text in processed.items():
   unique_words.update(text)
print(unique_words)
print(len(unique_words))
# Out:
# {'italian', 'home', 'building', 'recipe', 'pasta', 'right', 'summer', 'naples', 'cheese', 'wood-fired', 'variety', '10', 'idea', 'restaurant', 'foodie', 'scratch', 'technique', 'york', 'choose', 'prep', 'bread', 'cooking', 'traditional', 'homemade', 'dough', 'beginner', 'easy', 'city', 'baking', 'guide', 'meal', 'new', 'tip', 'make', 'temperature', 'us', 'oven', 'best', 'healthy', 'outdoor', 'top', 'control', 'history', 'pizza', 'flour'}
# 45

# %%
from collections import defaultdict
inverted_index = defaultdict(set)

for doc_id, text in processed.items():
  for word in text:
    inverted_index[word].add(doc_id)
print (inverted_index)
# Out:
# defaultdict(<class 'set'>, {'best': {'S1', 'S8', 'S2'}, 'homemade': {'S1', 'S9'}, 'pizza': {'S6', 'S8', 'S9', 'S5', 'S2', 'S1', 'S3'}, 'recipe': {'S1', 'S4', 'S2'}, 'beginner': {'S1', 'S3'}, 'make': {'S2'}, 'dough': {'S2'}, 'scratch': {'S2'}, 'top': {'S3'}, '10': {'S3'}, 'tip': {'S3', 'S7'}, 'baking': {'S3'}, 'home': {'S3'}, 'easy': {'S4'}, 'pasta': {'S4'}, 'italian': {'S4', 'S10'}, 'cooking': {'S7', 'S4', 'S10'}, 'technique': {'S4'}, 'guide': {'S5'}, 'building': {'S5'}, 'outdoor': {'S5'}, 'oven': {'S5'}, 'summer': {'S5'}, 'history': {'S6'}, 'naples': {'S6'}, 'new': {'S6'}, 'york': {'S6'}, 'foodie': {'S6'}, 'healthy': {'S7'}, 'meal': {'S7'}, 'prep': {'S7'}, 'idea': {'S7'}, 'temperature': {'S7'}, 'control': {'S7'}, 'wood-fired': {'S8'}, 'restaurant': {'S8'}, 'city': {'S8'}, 'choose': {'S9'}, 'right': {'S9'}, 'flour': {'S9'}, 'bread': {'S9'}, 'cheese': {'S10'}, 'variety': {'S10'}, 'us': {'S10'}, 'traditional': {'S10'}})

# %%
for word in unique_words:
  docs = sorted(inverted_index[word])
  print(word, " : ", docs)
# Out:
# italian  :  ['S10', 'S4']
# home  :  ['S3']
# building  :  ['S5']
# recipe  :  ['S1', 'S2', 'S4']
# pasta  :  ['S4']
# right  :  ['S9']
# summer  :  ['S5']
# naples  :  ['S6']
# cheese  :  ['S10']
# wood-fired  :  ['S8']
# variety  :  ['S10']
# 10  :  ['S3']
# idea  :  ['S7']
# restaurant  :  ['S8']
# foodie  :  ['S6']
# scratch  :  ['S2']
# technique  :  ['S4']
# york  :  ['S6']
# choose  :  ['S9']
# prep  :  ['S7']
# bread  :  ['S9']
# cooking  :  ['S10', 'S4', 'S7']
# traditional  :  ['S10']
# homemade  :  ['S1', 'S9']
# dough  :  ['S2']
# beginner  :  ['S1', 'S3']
# easy  :  ['S4']
# city  :  ['S8']
# baking  :  ['S3']
# guide  :  ['S5']
# meal  :  ['S7']
# new  :  ['S6']
# tip  :  ['S3', 'S7']
# make  :  ['S2']
# temperature  :  ['S7']
# us  :  ['S10']
# oven  :  ['S5']
# best  :  ['S1', 'S2', 'S8']
# healthy  :  ['S7']
# outdoor  :  ['S5']
# top  :  ['S3']
# control  :  ['S7']
# history  :  ['S6']
# pizza  :  ['S1', 'S2', 'S3', 'S5', 'S6', 'S8', 'S9']
# flour  :  ['S9']

# %% [markdown]
# # TF-IDF — From Zero to Search Engine
#
# **What you'll learn in this notebook:**
# - Why simple word counting fails for search
# - What TF (Term Frequency) measures
# - What IDF (Inverse Document Frequency) measures
# - How TF × IDF = a powerful relevance score
# - Build a working search engine from scratch
#
# ---
#
# ## The Problem: Why Counting Words Fails
#
# Imagine you have 3 documents and someone searches for **"pizza recipe"**.
#
# A naive approach: count how many times each search word appears in each document.
#
# But there's a flaw — the word **"the"** appears in almost every document. If you count it, documents with lots of "the" will rank higher even if they're completely irrelevant.
#
# **TF-IDF solves this by:**
# - ✅ Rewarding words that appear often **in this specific document** (TF)
# - ✅ Penalizing words that appear in **every document** (IDF)
# - ✅ Multiplying them together to get a final relevance score

# %%
# Our mini document collection — 10 food/cooking articles
# Think of these as web pages returned by a crawler

documents = {
    "S1":  "The best homemade pizza recipe for beginners",
    "S2":  "How to make the best pizza dough from scratch recipe",
    "S3":  "Top 10 tips for baking pizza at home for beginners",
    "S4":  "Easy pasta recipes and Italian cooking techniques",
    "S5":  "A guide to building your own outdoor pizza oven in summer",
    "S6":  "The history of pizza from Naples to New York for foodies",
    "S7":  "Healthy meal prep ideas and cooking tips for temperature control",
    "S8":  "Best wood-fired pizza restaurants in the best cities",
    "S9":  "How to choose the right flour for homemade bread and pizza",
    "S10": "Italian cheese varieties and their uses in traditional cooking",
}

print(f"Total documents: {len(documents)}")
print()
for doc_id, text in documents.items():
    print(f"  {doc_id:4s}: {text}")
# Out:
# Total documents: 10
#
#   S1  : The best homemade pizza recipe for beginners
#   S2  : How to make the best pizza dough from scratch recipe
#   S3  : Top 10 tips for baking pizza at home for beginners
#   S4  : Easy pasta recipes and Italian cooking techniques
#   S5  : A guide to building your own outdoor pizza oven in summer
#   S6  : The history of pizza from Naples to New York for foodies
#   S7  : Healthy meal prep ideas and cooking tips for temperature control
#   S8  : Best wood-fired pizza restaurants in the best cities
#   S9  : How to choose the right flour for homemade bread and pizza
#   S10 : Italian cheese varieties and their uses in traditional cooking

# %% [markdown]
# ---
#
# ## Demonstrate the Naive Counting Problem
#
# Before building TF-IDF, let's see WHY simple counting fails.
#
# We'll count how many times each word in the query `"best pizza recipe"` appears in each document — and rank by raw count.

# %%
# Naive approach: just count query word occurrences

query_words = ["best", "pizza", "recipe"]

print("Naive word count scores for query: 'best pizza recipe'")
print(f"{'Doc':<5} {'best':>6} {'pizza':>6} {'recipe':>8} {'TOTAL':>7}")
print("-" * 38)

naive_scores = {}
for doc_id, text in documents.items():
    words = text.lower().split()            # split into lowercase words
    count_best   = words.count("best")
    count_pizza  = words.count("pizza")
    count_recipe = words.count("recipe")
    total = count_best + count_pizza + count_recipe
    naive_scores[doc_id] = total
    if total > 0:
        print(f"{doc_id:<5} {count_best:>6} {count_pizza:>6} {count_recipe:>8} {total:>7}")

print()
print("Ranked by naive count:")
for rank, (doc_id, score) in enumerate(
    sorted(naive_scores.items(), key=lambda x: -x[1])[:5], 1
):
    print(f"  {rank}. {doc_id} (count={score}) — {documents[doc_id]}")

print()
print("⚠️  Problem: S8 ranks higher (in this case #3) only because 'best' appears TWICE.")
print("   But S1 is clearly the most relevant: 'best homemade PIZZA RECIPE for beginners'")
# Out:
# Naive word count scores for query: 'best pizza recipe'
# Doc     best  pizza   recipe   TOTAL
# --------------------------------------
# S1         1      1        1       3
# S2         1      1        1       3
# S3         0      1        0       1
# S5         0      1        0       1
# S6         0      1        0       1
# S8         2      1        0       3
# S9         0      1        0       1
#
# Ranked by naive count:
#   1. S1 (count=3) — The best homemade pizza recipe for beginners
#   2. S2 (count=3) — How to make the best pizza dough from scratch recipe
#   3. S8 (count=3) — Best wood-fired pizza restaurants in the best cities
#   4. S3 (count=1) — Top 10 tips for baking pizza at home for beginners
#   5. S5 (count=1) — A guide to building your own outdoor pizza oven in summer
#
# ⚠️  Problem: S8 ranks higher (in this case #3) only because 'best' appears TWICE.
#    But S1 is clearly the most relevant: 'best homemade PIZZA RECIPE for beginners'

# %% [markdown]
# ---
#
# ## Text Preprocessing (Getting Documents Ready)
#
# Before calculating TF-IDF, we need to clean the text. Raw text is messy:
# - "Recipe" and "recipe" should be the same word → **lowercase**
# - "the", "a", "and" are noise → **remove stop words**
# - "recipes" and "recipe" mean the same thing → **stemming**
#
# Think of preprocessing as washing vegetables before cooking — you can't skip it.

# %% [markdown]
# ## Example — Text Processing (S1)

# %%
# --- Step 2a: Tokenise (split text into individual words) ---

def tokenise(text):
    # 👇 .lower() makes 'Pizza' == 'pizza', then .split() splits on spaces
    return text.lower().split()

example = documents["S1"]
tokens = tokenise(example)
print(f"Original : {example}")
print(f"Tokenised: {tokens}")
# Out:
# Original : The best homemade pizza recipe for beginners
# Tokenised: ['the', 'best', 'homemade', 'pizza', 'recipe', 'for', 'beginners']

# %%
# --- Step 2b: Remove stop words ---
# Stop words are high-frequency, low-meaning words.
# They appear in EVERY document, so they have zero discriminating power.

STOP_WORDS = {
    'the', 'a', 'an', 'and', 'or', 'but', 'in', 'on', 'at',
    'to', 'for', 'of', 'is', 'it', 'from', 'how', 'your',
    'their', 'own', 'that', 'this'
}

def remove_stop_words(tokens):
    # 👇 Keep only tokens that are NOT in the stop words set
    return [t for t in tokens if t not in STOP_WORDS]

tokens   = tokenise(documents["S1"])
filtered = remove_stop_words(tokens)

print(f"Before stop word removal: {tokens}")
print(f"After  stop word removal: {filtered}")
removed = set(tokens) - set(filtered)
print(f"Removed: {removed}  ← these words tell us nothing useful")
# Out:
# Before stop word removal: ['the', 'best', 'homemade', 'pizza', 'recipe', 'for', 'beginners']
# After  stop word removal: ['best', 'homemade', 'pizza', 'recipe', 'beginners']
# Removed: {'for', 'the'}  ← these words tell us nothing useful

# %%
# --- Step 2c: Stemming ---
# "recipes", "recipe" → same root "recip"
# "cooking", "cooked", "cook" → same root "cook"
#
# We use a manual lookup table here (a real system uses NLTK's PorterStemmer)
# The goal: treat different forms of the same word as ONE word

STEM_RULES = {
    'recipes': 'recip', 'recipe': 'recip',
    'baking': 'bake',   'cooking': 'cook',
    'homemade': 'homemad', 'beginners': 'beginn',
    'building': 'build',   'cities': 'citi',
    'varieties': 'varieti', 'ideas': 'idea',
    'techniques': 'techniqu', 'traditional': 'tradit',
    'restaurants': 'restaur', 'healthy': 'healthi',
    'uses': 'use',     'tips': 'tip',
    'choose': 'choos', 'fired': 'fire',
}

def stem(token):
    # 👇 If we have a rule for this word, use the root; otherwise keep as-is
    return STEM_RULES.get(token, token)

# Show stemming in action
demo_words = ['recipes', 'recipe', 'baking', 'cooking', 'beginners', 'techniques']
print("Stemming examples:")
for w in demo_words:
    print(f"  {w:15s} → {stem(w)}")

print()
print("Why this matters: a search for 'recipe' will now match documents")
print("that say 'recipes' — because both map to 'recip'")
# Out:
# Stemming examples:
#   recipes         → recip
#   recipe          → recip
#   baking          → bake
#   cooking         → cook
#   beginners       → beginn
#   techniques      → techniqu
#
# Why this matters: a search for 'recipe' will now match documents
# that say 'recipes' — because both map to 'recip'

# %% [markdown]
# ## Full Pipeline — All Documents

# %%
# --- Step 2d: Full pipeline — combine all 3 steps ---

def process(text):
    tokens  = tokenise(text)             # Step 1: lowercase + split
    cleaned = remove_stop_words(tokens)  # Step 2: remove noise words
    stemmed = [stem(t) for t in cleaned] # Step 3: collapse word variants
    return stemmed

# Process ALL documents and store the result
processed = {}
for doc_id, text in documents.items():
    processed[doc_id] = process(text)

print("Processed documents (these are what TF-IDF works on):")
print()
for doc_id, terms in processed.items():
    print(f"  {doc_id:4s}: {terms}")
# Out:
# Processed documents (these are what TF-IDF works on):
#
#   S1  : ['best', 'homemad', 'pizza', 'recip', 'beginn']
#   S2  : ['make', 'best', 'pizza', 'dough', 'scratch', 'recip']
#   S3  : ['top', '10', 'tip', 'bake', 'pizza', 'home', 'beginn']
#   S4  : ['easy', 'pasta', 'recip', 'italian', 'cook', 'techniqu']
#   S5  : ['guide', 'build', 'outdoor', 'pizza', 'oven', 'summer']
#   S6  : ['history', 'pizza', 'naples', 'new', 'york', 'foodies']
#   S7  : ['healthi', 'meal', 'prep', 'idea', 'cook', 'tip', 'temperature', 'control']
#   S8  : ['best', 'wood-fired', 'pizza', 'restaur', 'best', 'citi']
#   S9  : ['choos', 'right', 'flour', 'homemad', 'bread', 'pizza']
#   S10 : ['italian', 'cheese', 'varieti', 'use', 'tradit', 'cook']

# %% [markdown]
# ---
#
# ## TF — Term Frequency
#
# **Formula:**
# ```
# TF(word, document) = (number of times word appears in document)
#                      ─────────────────────────────────────────
#                      (total number of words in document)
# ```
#
# **Why divide by total words?**
# A 1000-word document will naturally have higher counts than a 10-word document. Dividing normalizes for document length — we care about *proportion*, not raw count.
#
# **Range:** 0.0 (word not in doc) to 1.0 (document is one repeated word)

# %%
# TF = count of word in this doc / total words in this doc

def tf(term, doc_terms):
    """
    term      : the word we're scoring (already stemmed/processed)
    doc_terms : list of processed tokens in the document
    """
    count      = doc_terms.count(term)  # 👇 how many times does 'term' appear?
    total      = len(doc_terms)         # 👇 total words in this document
    return count / total                # 👇 proportion of this doc that is 'term'

# --- Demonstration ---
print("TF scores for the word 'pizza' across all documents:")
print()
print(f"  {'Doc':<5} {'Tokens':<45} {'pizza count':>12} {'total words':>12} {'TF':>8}")
print("  " + "-" * 85)

for doc_id, terms in processed.items():
    score = tf("pizza", terms)
    count = terms.count("pizza")
    marker = " ←" if score > 0 else ""
    print(f"  {doc_id:<5} {str(terms):<45} {count:>12} {len(terms):>12} {score:>8.4f}{marker}")
# Out:
# TF scores for the word 'pizza' across all documents:
#
#   Doc   Tokens                                         pizza count  total words       TF
#   -------------------------------------------------------------------------------------
#   S1    ['best', 'homemad', 'pizza', 'recip', 'beginn']            1            5   0.2000 ←
#   S2    ['make', 'best', 'pizza', 'dough', 'scratch', 'recip']            1            6   0.1667 ←
#   S3    ['top', '10', 'tip', 'bake', 'pizza', 'home', 'beginn']            1            7   0.1429 ←
#   S4    ['easy', 'pasta', 'recip', 'italian', 'cook', 'techniqu']            0            6   0.0000
#   S5    ['guide', 'build', 'outdoor', 'pizza', 'oven', 'summer']            1            6   0.1667 ←
#   S6    ['history', 'pizza', 'naples', 'new', 'york', 'foodies']            1            6   0.1667 ←
#   S7    ['healthi', 'meal', 'prep', 'idea', 'cook', 'tip', 'temperature', 'control']            0            8   0.0000
#   S8    ['best', 'wood-fired', 'pizza', 'restaur', 'best', 'citi']            1            6   0.1667 ←
#   S9    ['choos', 'right', 'flour', 'homemad', 'bread', 'pizza']            1            6   0.1667 ←
#   S10   ['italian', 'cheese', 'varieti', 'use', 'tradit', 'cook']            0            6   0.0000

# %%
# Let's also look at TF for 'best' — this will reveal TF's weakness

print("TF scores for the word 'best':")
print()
for doc_id, terms in processed.items():
    score = tf("best", terms)
    if score > 0:
        print(f"  {doc_id}: TF = {score:.4f}  (appears {terms.count('best')}x in {len(terms)} words) — {documents[doc_id]}")

print()
print("⚠️  TF alone still has a problem:")
print("   TF doesn't know whether 'best' appears in many documents or just a few.")
print("   A word that appears in ALL 10 docs tells us nothing about which doc to pick.")
print("   That's what IDF fixes.")
# Out:
# TF scores for the word 'best':
#
#   S1: TF = 0.2000  (appears 1x in 5 words) — The best homemade pizza recipe for beginners
#   S2: TF = 0.1667  (appears 1x in 6 words) — How to make the best pizza dough from scratch recipe
#   S8: TF = 0.3333  (appears 2x in 6 words) — Best wood-fired pizza restaurants in the best cities
#
# ⚠️  TF alone still has a problem:
#    TF doesn't know whether 'best' appears in many documents or just a few.
#    A word that appears in ALL 10 docs tells us nothing about which doc to pick.
#    That's what IDF fixes.

# %% [markdown]
# ---
#
# ## IDF — Inverse Document Frequency
#
# **Formula:**
# ```
# IDF(word) = log( total number of documents )
#                  ─────────────────────────
#                  number of docs containing word
# ```
#
# **Intuition:**
# - If a word appears in 1 out of 10 docs → `log(10/1) = 2.3` → HIGH score (rare = informative)
# - If a word appears in 10 out of 10 docs → `log(10/10) = 0` → ZERO score (everywhere = useless)
#
# **Why `log`?**
# Without log, a word in 1 doc would score 10, and a word in 2 docs would score 5. That's too aggressive. Log compresses the scale — the difference between 1 doc and 2 docs is much less dramatic than the difference between 1 and 1000.

# %%
import math

def idf(term, all_docs):
    """
    term     : the word we're scoring
    all_docs : dict of {doc_id: [processed terms]}
    """
    N  = len(all_docs)                                       # 👇 total number of documents
    df = sum(1 for doc in all_docs.values() if term in doc)  # 👇 docs that contain this term
    if df == 0:
        return 0                                             # 👇 word never appears → score 0
    return math.log(N / df)                                  # 👇 log(N/df) = IDF

# --- See IDF for various words ---
words_to_check = ['pizza', 'best', 'recip', 'cook', 'beginn', 'foodi', 'naples', 'the']

print(f"IDF scores across {len(processed)} documents:")
print()
print(f"  {'Word':<15} {'Docs with it':>13} {'IDF score':>10}  Meaning")
print("  " + "-" * 65)

for word in words_to_check:
    df    = sum(1 for doc in processed.values() if word in doc)
    score = idf(word, processed)
    if df > 0:
        meaning = "very common → low signal" if score < 0.5 else (
                  "common"                   if score < 1.0 else (
                  "moderately rare"          if score < 2.0 else
                  "RARE → high signal"))
        print(f"  {word:<15} {df:>5}/{len(processed):<8} {score:>10.4f}  {meaning}")
# Out:
# IDF scores across 10 documents:
#
#   Word             Docs with it  IDF score  Meaning
#   -----------------------------------------------------------------
#   pizza               7/10           0.3567  very common → low signal
#   best                3/10           1.2040  moderately rare
#   recip               3/10           1.2040  moderately rare
#   cook                3/10           1.2040  moderately rare
#   beginn              2/10           1.6094  moderately rare
#   naples              1/10           2.3026  RARE → high signal

# %%
# Visual proof: why log() matters
# Without log, the score would be too extreme

N = 10  # our 10 documents

print("Effect of log() on IDF scores:")
print()
print(f"  {'Docs with word':>15} {'Raw N/df':>10} {'With log()':>12}  Interpretation")
print("  " + "-" * 65)

for df in [10, 8, 5, 3, 2, 1]:
    raw  = N / df
    with_log = math.log(N / df)
    interp = "common" if df >= 7 else ("moderate" if df >= 3 else "rare")
    print(f"  {df:>5}/{N:<10} {raw:>10.2f} {with_log:>12.4f}  {interp}")

print()
print("💡 Without log: word in 1 doc scores 10.0, word in 2 docs scores 5.0 (2x difference)")
print("   With log:    word in 1 doc scores 2.30, word in 2 docs scores 1.61 (much gentler)")
print("   Log prevents rare words from completely dominating the score.")
# Out:
# Effect of log() on IDF scores:
#
#    Docs with word   Raw N/df   With log()  Interpretation
#   -----------------------------------------------------------------
#      10/10               1.00       0.0000  common
#       8/10               1.25       0.2231  common
#       5/10               2.00       0.6931  moderate
#       3/10               3.33       1.2040  moderate
#       2/10               5.00       1.6094  rare
#       1/10              10.00       2.3026  rare
#
# 💡 Without log: word in 1 doc scores 10.0, word in 2 docs scores 5.0 (2x difference)
#    With log:    word in 1 doc scores 2.30, word in 2 docs scores 1.61 (much gentler)
#    Log prevents rare words from completely dominating the score.

# %% [markdown]
# ## Reasoning for Log Function
#
# Okay, imagine you have a special flashlight for finding important words! If a word is super, super rare, like finding a unicorn, that flashlight wants to shine incredibly, blindingly bright! So bright that you can't even see the other words.
#
# But if we use a log function, it's like putting a dimmer switch on that super-bright flashlight. The unicorn-word's light is still very bright and important (because it's rare!), but it won't blind you completely. The light from a word that's a little less rare (like finding a special sparkly rock) will also be bright, but the difference between the unicorn's light and the rock's light won't be as crazy huge.
#
# So, the log function just makes sure that really rare words still get lots of attention, but they don't get so much attention that they unfairly make you ignore all the other important words!

# %% [markdown]
# ---
#
# ## TF-IDF = TF × IDF
#
# Now we multiply them together:
#
# ```
# TF-IDF(word, document) = TF(word, document)  ×  IDF(word)
# ```
#
# **What each combination means:**
#
# | TF | IDF | TF-IDF | Meaning |
# |---|---|---|---|
# | High | High | **High** | Word appears often in THIS doc AND is rare globally → very relevant |
# | High | Low | **Low** | Common word like "the" — appears everywhere, meaningless |
# | Low | High | **Medium** | Rare word but barely used in this doc → weak signal |
# | Low | Low | **Zero** | Common word barely used — total noise |

# %%
def tfidf(term, doc_terms, all_docs):
    """
    Final TF-IDF score for a term in a document.
    High score = this term is important TO THIS DOCUMENT specifically.
    """
    return tf(term, doc_terms) * idf(term, all_docs)

# --- Deep dive: score 'pizza' vs 'best' across all documents ---

print("TF-IDF comparison: 'pizza' vs 'best'")
print()
print(f"  {'IDF pizza':>10} = {idf('pizza', processed):.4f}  (pizza in {sum(1 for d in processed.values() if 'pizza' in d)}/10 docs)")
print(f"  {'IDF best' :>10} = {idf('best',  processed):.4f}  (best  in {sum(1 for d in processed.values() if 'best'  in d)}/10 docs)")
print()
print(f"  {'Doc':<5} {'TF(pizza)':>10} {'TF-IDF(pizza)':>14} {'TF(best)':>10} {'TF-IDF(best)':>13}")
print("  " + "-" * 55)

for doc_id, terms in processed.items():
    tf_pizza   = tf("pizza", terms)
    tf_best    = tf("best",  terms)
    tfidf_pizza = tfidf("pizza", terms, processed)
    tfidf_best  = tfidf("best",  terms, processed)
    if tf_pizza > 0 or tf_best > 0:
        print(f"  {doc_id:<5} {tf_pizza:>10.4f} {tfidf_pizza:>14.4f} {tf_best:>10.4f} {tfidf_best:>13.4f}")

print()
print("💡 Notice: even though 'pizza' appears in more docs than 'best',")
print("   the TF-IDF scores properly weight both based on their rarity.")
# Out:
# TF-IDF comparison: 'pizza' vs 'best'
#
#    IDF pizza = 0.3567  (pizza in 7/10 docs)
#     IDF best = 1.2040  (best  in 3/10 docs)
#
#   Doc    TF(pizza)  TF-IDF(pizza)   TF(best)  TF-IDF(best)
#   -------------------------------------------------------
#   S1        0.2000         0.0713     0.2000        0.2408
#   S2        0.1667         0.0594     0.1667        0.2007
#   S3        0.1429         0.0510     0.0000        0.0000
#   S5        0.1667         0.0594     0.0000        0.0000
#   S6        0.1667         0.0594     0.0000        0.0000
#   S8        0.1667         0.0594     0.3333        0.4013
#   S9        0.1667         0.0594     0.0000        0.0000
#
# 💡 Notice: even though 'pizza' appears in more docs than 'best',
#    the TF-IDF scores properly weight both based on their rarity.

# %% [markdown]
# ## Why Multiply TF & IDF?
#
# Imagine you're looking for your favorite toy in a big toy box. Some toys are really common, like building blocks, and you see them everywhere. Some toys are super special and rare, like a shiny, limited-edition action figure. And some toys are your absolute favorite, so you play with them a lot.
#
# *   **TF (Term Frequency)** is like saying: "How often do I see *this specific toy* in the *toy box I'm looking at right now*?" If you see your shiny action figure many times in one box, that box is probably very important for finding that action figure!
#
# *   **IDF (Inverse Document Frequency)** is like saying: "How rare or special is *this toy* across *all the toy boxes in the world*?" If it's a common building block, it's not very special. If it's your shiny action figure, it's super special and exciting when you find it!
#
# **Multiplying TF and IDF (TF-IDF)** is like putting those two ideas together:
#
# We want to find toy boxes that have a lot of your *favorite* toy (**high TF**) AND where that toy is super *special and rare* (**high IDF**).
#
# If a toy box has lots of a common building block (high TF, low IDF), it's not super exciting. But if a toy box has even one of your shiny, rare action figures (low TF, high IDF), that's pretty good. But if a toy box has *many* of your shiny, rare action figures (high TF, high IDF), that's the *best* toy box of all!
#
# ***So, multiplying them helps us find the toy boxes that are *most likely to have exactly what you're looking for* because they contain lots of special, important toys.***

# %%
# --- Score a full query: sum TF-IDF over all query terms ---
# For query "best pizza recipe":
#   score(doc) = TF-IDF("best", doc) + TF-IDF("pizza", doc) + TF-IDF("recip", doc)

query_raw   = "best pizza recipe"
query_terms = process(query_raw)   # run same preprocessing on the query!
print(f"Query: '{query_raw}'")
print(f"After preprocessing: {query_terms}")
print()

print(f"  {'Doc':<5} ", end="")
for t in query_terms:
    print(f" {t:>10}", end="")
print(f" {'TOTAL':>10}")
print("  " + "-" * (5 + 10 * len(query_terms) + 12))

all_scores = {}
for doc_id, terms in processed.items():
    per_term = {t: tfidf(t, terms, processed) for t in query_terms}
    total    = sum(per_term.values())
    all_scores[doc_id] = total
    if total > 0:
        print(f"  {doc_id:<5} ", end="")
        for t in query_terms:
            print(f" {per_term[t]:>10.4f}", end="")
        print(f" {total:>10.4f}")

print()
print("🏆 Ranked Results:")
for rank, (doc_id, score) in enumerate(
    sorted(all_scores.items(), key=lambda x: -x[1])[:5], 1
):
    print(f"  {rank}. {doc_id} (score: {score:.4f}) — {documents[doc_id]}")
# Out:
# Query: 'best pizza recipe'
# After preprocessing: ['best', 'pizza', 'recip']
#
#   Doc          best      pizza      recip      TOTAL
#   -----------------------------------------------
#   S1         0.2408     0.0713     0.2408     0.5529
#   S2         0.2007     0.0594     0.2007     0.4608
#   S3         0.0000     0.0510     0.0000     0.0510
#   S4         0.0000     0.0000     0.2007     0.2007
#   S5         0.0000     0.0594     0.0000     0.0594
#   S6         0.0000     0.0594     0.0000     0.0594
#   S8         0.4013     0.0594     0.0000     0.4608
#   S9         0.0000     0.0594     0.0000     0.0594
#
# 🏆 Ranked Results:
#   1. S1 (score: 0.5529) — The best homemade pizza recipe for beginners
#   2. S2 (score: 0.4608) — How to make the best pizza dough from scratch recipe
#   3. S8 (score: 0.4608) — Best wood-fired pizza restaurants in the best cities
#   4. S4 (score: 0.2007) — Easy pasta recipes and Italian cooking techniques
#   5. S5 (score: 0.0594) — A guide to building your own outdoor pizza oven in summer

# %% [markdown]
# ---
#
# ## Build a Complete Search Function
#
# Let's wrap everything into a clean `search()` function that:
# 1. Preprocesses the query (same pipeline as documents)
# 2. Uses an inverted index to find candidate documents fast
# 3. Scores candidates with TF-IDF
# 4. Returns ranked results

# %%
from collections import defaultdict

# --- Build an inverted index for fast lookup ---
# Instead of scanning all documents for every query,
# we pre-build a map: word → which documents contain it

inverted_index = defaultdict(set)           # maps term → set of doc_ids
for doc_id, terms in processed.items():
    for term in terms:
        inverted_index[term].add(doc_id)    # 👇 record that this doc contains this term

# Show the index for a few terms
print("Inverted index (term → documents that contain it):")
print()
for term in ['pizza', 'recip', 'cook', 'best', 'beginn', 'naples']:
    docs = sorted(inverted_index[term])
    print(f"  {term:<12} → {docs}")

print()
print("💡 For a query, we union the sets for each query word.")
print("   query 'pizza recipe' → pizza_docs ∪ recipe_docs = candidate set")
# Out:
# Inverted index (term → documents that contain it):
#
#   pizza        → ['S1', 'S2', 'S3', 'S5', 'S6', 'S8', 'S9']
#   recip        → ['S1', 'S2', 'S4']
#   cook         → ['S10', 'S4', 'S7']
#   best         → ['S1', 'S2', 'S8']
#   beginn       → ['S1', 'S3']
#   naples       → ['S6']
#
# 💡 For a query, we union the sets for each query word.
#    query 'pizza recipe' → pizza_docs ∪ recipe_docs = candidate set

# %%
def search(query_text, top_k=5, verbose=True):
    """
    Full TF-IDF search:
    1. Preprocess query  (same pipeline as documents)
    2. Lookup candidates via inverted index  (fast!)
    3. Score each candidate with TF-IDF
    4. Return top_k ranked results
    """
    # Step 1: preprocess the query the same way we processed documents
    query_terms = process(query_text)

    # Step 2: find candidate documents using the inverted index
    # Union of all doc sets for each query term
    candidates = set()
    for term in query_terms:
        candidates |= inverted_index.get(term, set())  # 👇 |= is set union

    # Step 3: score each candidate
    scores = {}
    for doc_id in candidates:
        # Sum TF-IDF score for EACH query term in this document
        scores[doc_id] = sum(
            tfidf(t, processed[doc_id], processed) for t in query_terms
        )

    # Step 4: sort by score descending, take top k
    ranked = sorted(scores.items(), key=lambda x: -x[1])[:top_k]

    if verbose:
        print(f"Query: '{query_text}'")
        print(f"Preprocessed: {query_terms}")
        print(f"Candidates: {sorted(candidates)} ({len(candidates)} docs to score)")
        print()
        print(f"Top {top_k} Results:")
        for rank, (doc_id, score) in enumerate(ranked, 1):
            print(f"  {rank}. [{score:.4f}] {documents[doc_id]}")
        print()

    return ranked

# %%
# --- Try different queries ---

print("=" * 60)
search("best pizza recipe")

print("=" * 60)
search("Italian traditional cooking")

print("=" * 60)
search("homemade bread flour")

print("=" * 60)
search("healthy meal ideas")
# Out:
# ============================================================
# Query: 'best pizza recipe'
# Preprocessed: ['best', 'pizza', 'recip']
# Candidates: ['S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S8', 'S9'] (8 docs to score)
#
# Top 5 Results:
#   1. [0.5529] The best homemade pizza recipe for beginners
#   2. [0.4608] How to make the best pizza dough from scratch recipe
#   3. [0.4608] Best wood-fired pizza restaurants in the best cities
#   4. [0.2007] Easy pasta recipes and Italian cooking techniques
#   5. [0.0594] A guide to building your own outdoor pizza oven in summer
#
# ============================================================
# Query: 'Italian traditional cooking'
# Preprocessed: ['italian', 'tradit', 'cook']
# Candidates: ['S10', 'S4', 'S7'] (3 docs to score)
#
# Top 5 Results:
#   1. [0.8527] Italian cheese varieties and their uses in traditional cooking
#   2. [0.4689] Easy pasta recipes and Italian cooking techniques
#   3. [0.1505] Healthy meal prep ideas and cooking tips for temperature control
#
# ============================================================
# Query: 'homemade bread flour'
# Preprocessed: ['homemad', 'bread', 'flour']
# Candidates: ['S1', 'S9'] (2 docs to score)
#
# Top 5 Results:
#   1. [1.0358] How to choose the right flour for homemade bread and pizza
#   2. [0.3219] The best homemade pizza recipe for beginners
#
# ============================================================
# Query: 'healthy meal ideas'
# Preprocessed: ['healthi', 'meal', 'idea']
# Candidates: ['S7'] (1 docs to score)
#
# Top 5 Results:
#   1. [0.8635] Healthy meal prep ideas and cooking tips for temperature control
# [('S7', 0.8634694098727672)]

# %%
search("italian pasta")
# Out:
# Query: 'italian pasta'
# Preprocessed: ['italian', 'pasta']
# Candidates: ['S10', 'S4'] (2 docs to score)
#
# Top 5 Results:
#   1. [0.6520] Easy pasta recipes and Italian cooking techniques
#   2. [0.2682] Italian cheese varieties and their uses in traditional cooking
# [('S4', 0.6520038342380243), ('S10', 0.26823965207235)]

# %% [markdown]
# ---
#
# ## Where TF-IDF Fails
#
# TF-IDF is powerful but has known limitations. Understanding these failures is exactly how you know when to move to something better.

# %%
# FAILURE 1: Synonyms are invisible to TF-IDF
# TF-IDF treats words as exact strings — 'car' and 'automobile' are completely different.

print("FAILURE 1: Synonyms")
print("Query: 'automobile' — but all our documents say 'car' or 'vehicle'")

# Add a test doc
test_docs = {
    "D1": "car racing tips and tricks",
    "D2": "vehicle maintenance guide",
    "D3": "automobile history and evolution",
}
processed_test = {k: process(v) for k, v in test_docs.items()}
inv_test = defaultdict(set)
for doc_id, terms in processed_test.items():
    for t in terms: inv_test[t].add(doc_id)

query_terms = process("car")
print(f"  Query 'car' preprocessed: {query_terms}")
print(f"  Docs containing 'car': {sorted(inv_test.get('car', set()))}")
print(f"  Docs containing 'automobil': {sorted(inv_test.get('automobil', set()))}")
print()
print("  'car' matches D1 but not D3 ('automobile')")
print("  Even though D3 is clearly about the same topic!")
print()
print("→ FIX: Word embeddings (Word2Vec, BERT) understand that car ≈ automobile")
# Out:
# FAILURE 1: Synonyms
# Query: 'automobile' — but all our documents say 'car' or 'vehicle'
#   Query 'car' preprocessed: ['car']
#   Docs containing 'car': ['D1']
#   Docs containing 'automobil': []
#
#   'car' matches D1 but not D3 ('automobile')
#   Even though D3 is clearly about the same topic!
#
# → FIX: Word embeddings (Word2Vec, BERT) understand that car ≈ automobile

# %%
# FAILURE 2: Word order doesn't matter
# 'dog bites man' and 'man bites dog' have the SAME TF-IDF scores

print("FAILURE 2: Word order is ignored")
print()

sent1 = "the dog bites the man"
sent2 = "the man bites the dog"

tokens1 = process(sent1)
tokens2 = process(sent2)

print(f"Sentence 1 tokens: {tokens1}")
print(f"Sentence 2 tokens: {tokens2}")
print()

# The token bags are identical (same words, different order)
print(f"Same tokens? {sorted(tokens1) == sorted(tokens2)}")
print()
print("TF-IDF gives IDENTICAL scores to both sentences for any query.")
print("It has no concept of meaning, syntax, or order.")
print()
print("→ FIX: Transformers (BERT, GPT) read the full sequence in order")
# Out:
# FAILURE 2: Word order is ignored
#
# Sentence 1 tokens: ['dog', 'bites', 'man']
# Sentence 2 tokens: ['man', 'bites', 'dog']
#
# Same tokens? True
#
# TF-IDF gives IDENTICAL scores to both sentences for any query.
# It has no concept of meaning, syntax, or order.
#
# → FIX: Transformers (BERT, GPT) read the full sequence in order

# %%
# FAILURE 3: New words have zero IDF
# If a word never appeared in training documents, IDF = 0
# Called the 'Out of Vocabulary' (OOV) problem

print("FAILURE 3: Out-of-vocabulary (OOV) words")
print()

new_word = "sourdough"
df = sum(1 for doc in processed.values() if new_word in doc)
score = idf(new_word, processed)

print(f"  Word: '{new_word}'")
print(f"  Appears in {df} documents")
print(f"  IDF = {score}")
print(f"  TF-IDF for any doc = 0 × 0 = 0")
print()
print("  If someone searches for 'sourdough pizza', we return nothing!")
print()
print("→ FIX: BM25 handles this with smoothing; embeddings generalize to unseen words")
# Out:
# FAILURE 3: Out-of-vocabulary (OOV) words
#
#   Word: 'sourdough'
#   Appears in 0 documents
#   IDF = 0
#   TF-IDF for any doc = 0 × 0 = 0
#
#   If someone searches for 'sourdough pizza', we return nothing!
#
# → FIX: BM25 handles this with smoothing; embeddings generalize to unseen words

# %% [markdown]
# ---
#
# ## Summary: What TF-IDF Does (and Doesn't Do)
#
# | | TF-IDF | Word Embeddings (next) |
# |---|---|---|
# | Handles exact word matches | ✅ Yes | ✅ Yes |
# | Handles synonyms | ❌ No | ✅ Yes |
# | Understands word order | ❌ No | ✅ Yes |
# | Handles new/rare words | ❌ No | ✅ Yes |
# | Fast to compute | ✅ Very fast | ⚠️ Slower |
# | Easy to explain | ✅ Fully transparent | ❌ Black box |
# | No GPU needed | ✅ Yes | ⚠️ Preferred |
#
# **When to use TF-IDF:**
# - Keyword search on large document collections
# - When exact term matching matters (legal, medical, code search)
# - As a fast first-pass filter before a slower re-ranker
# - When you need full explainability (why did this doc rank here?)
#
# **What's next:**
# Word2Vec and sentence embeddings turn words into vectors that *understand meaning* — so "pizza" and "Italian dish" become close in vector space. That's what M00 theory covers next.

# %%
# Final recap: run the full pipeline end-to-end in one cell

print("=" * 55)
print(" FULL TF-IDF PIPELINE RECAP")
print("=" * 55)
print()

pipeline_steps = [
    ("1. Tokenise",         "Split text into lowercase words"),
    ("2. Stop words",       "Remove 'the', 'a', 'and', ..."),
    ("3. Stem",             "'recipes' → 'recip', 'cooking' → 'cook'"),
    ("4. Build index",      "Map each term → which docs contain it"),
    ("5. TF",               "Word count in this doc / total words in this doc"),
    ("6. IDF",              "log(total docs / docs with this word)"),
    ("7. TF-IDF",           "TF × IDF = relevance score"),
    ("8. Rank",             "Sum TF-IDF over query terms, sort descending"),
]
for step, desc in pipeline_steps:
    print(f"  {step:<20} {desc}")

print()
print("Try your own query:")
user_query = "homemade pizza beginners"   # 👈 change this to anything!
search(user_query)
# Out:
# =======================================================
#  FULL TF-IDF PIPELINE RECAP
# =======================================================
#
#   1. Tokenise          Split text into lowercase words
#   2. Stop words        Remove 'the', 'a', 'and', ...
#   3. Stem              'recipes' → 'recip', 'cooking' → 'cook'
#   4. Build index       Map each term → which docs contain it
#   5. TF                Word count in this doc / total words in this doc
#   6. IDF               log(total docs / docs with this word)
#   7. TF-IDF            TF × IDF = relevance score
#   8. Rank              Sum TF-IDF over query terms, sort descending
#
# Try your own query:
# Query: 'homemade pizza beginners'
# Preprocessed: ['homemad', 'pizza', 'beginn']
# Candidates: ['S1', 'S2', 'S3', 'S5', 'S6', 'S8', 'S9'] (7 docs to score)
#
# Top 5 Results:
#   1. [0.7151] The best homemade pizza recipe for beginners
#   2. [0.3277] How to choose the right flour for homemade bread and pizza
#   3. [0.2809] Top 10 tips for baking pizza at home for beginners
#   4. [0.0594] A guide to building your own outdoor pizza oven in summer
#   5. [0.0594] The history of pizza from Naples to New York for foodies
# [('S1', 0.7151101537613866),
#  ('S9', 0.3276854760621387),
#  ('S3', 0.28087326519611894),
#  ('S5', 0.05944582398978873),
#  ('S6', 0.05944582398978873)]
